# %% [markdown]
# ## Test our saved model
#
# We saved a model in a previous notebook.
#
# Let's load it in and ensure we can make predictions on it!

# %%
# import
import joblib
import pandas as pd

# %%
# load in the model

model = joblib.load("./../models/model.joblib")

type(model)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model.coef_
# Out:
# array([   114.25762724, -29167.93893539,  25630.35197597])

# %% [markdown]
# ---
#
# Can we make a prediction?

# %%
pred = pd.DataFrame(
    {
    "sqft": [2000],
    "bedrooms": [3],
    "bathrooms": [2]
})

pred
# Out:
#    sqft  bedrooms  bathrooms
# 0  2000         3          2

# %%
model.predict(pred)[0]
# Out:
# 243516.5620830612
